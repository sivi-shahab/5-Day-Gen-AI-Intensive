# %% [markdown]
# <a href="https://colab.research.google.com/github/sivi-shahab/5-Day-Gen-AI-Intensive/blob/main/Lesson_3_Pagination_%26_Authentication_%26_dlt_Configuration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Recap of [Lesson 2](https://colab.research.google.com/drive/1tc94GvIoYXmYrjUibDhY_9iPR5zA0Eyw?usp=sharing) 👩‍💻🚀**
#
# 1.  Used `@dlt.resource` to load and query data like lists, dataframes, and REST API responses into DuckDB.
# 2.  Grouped multiple resources into a single `@dlt.source` for better organization and efficiency.
# 3.  Used `@dlt.transformer` to process and enrich data between resources.
#
# Next: Dive deeper into building dlt pipelines using pagination, authentication and dlt configuration! 🚀

# %% [markdown]
# ---
#
# # **Pagination & Authentication & dlt Configuration** 🤫🔩
#
# **Here, you will learn how to:**
# - Use pagination for RestAPIs.
# - Use environment variables to handle both secrets & configs.
# - Add values to `secrets.toml` or `config.toml`.
#
# To read more about credentails refer to [dlt documentation](https://dlthub.com/docs/general-usage/credentials/) here.

# %% [markdown]
# In previous lesson we loaded data from GitHub API  to DuckDB,

# %%
# %%capture
# !pip install dlt

# %%
import dlt
from dlt.sources.helpers import requests


# define dlt resources
@dlt.resource
def github_events():
    url = "https://api.github.com/orgs/dlt-hub/events"
    response = requests.get(url)
    yield response.json()


# define dlt pipeline
pipeline = dlt.pipeline(destination="duckdb")

# run dlt pipeline
load_info = pipeline.run(github_events)
print(load_info)

# explore loaded data
pipeline.dataset(dataset_type="default").github_events.df()
# Out:
# Pipeline dlt_colab_kernel_launcher load step completed in 2.62 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset dlt_colab_kernel_launcher_dataset
# The duckdb destination used duckdb:////content/dlt_colab_kernel_launcher.duckdb location to store data
# Load package 1736683811.2233155 is LOADED and contains no failed jobs
#              id               type  actor__id    actor__login  \
# 0   45479602099  IssueCommentEvent   40209326    netlify[bot]
# 1   45479591868   PullRequestEvent  101326085      jonbiemond
# 2   45479170580  IssueCommentEvent   40209326    netlify[bot]
# 3   45479168109   PullRequestEvent  101326085      jonbiemond
# 4   45478875291          ForkEvent  101326085      jonbiemond
# 5   45478872231        IssuesEvent  101326085      jonbiemond
# 6   45476741016         WatchEvent      14818           yatsu
# 7   45474297475         WatchEvent    5054710        weisberg
# 8   45474270460         WatchEvent    5054710        weisberg
# 9   45463313609         WatchEvent    6351623           BViki
# 10  45463313254         WatchEvent    6351623           BViki
# 11  45457712617          ForkEvent   73990893         tmdc-io
# 12  45456064885         WatchEvent     251088       joshklein
# 13  45455808049         WatchEvent    6808348        dannyeuu
# 14  45451458535  IssueCommentEvent    1155738           sh-rp
# 15  45451457932   PullRequestEvent    1155738           sh-rp
# 16  45451393410         WatchEvent   65499149       anhvh1408
# 17  45449146431         WatchEvent    2380200       noitcerid
# 18  45443153175         WatchEvent   15611560    neuralsignal
# 19  45440476325         WatchEvent    4449383        yanchick
# 20  45439477176  IssueCommentEvent    1155738           sh-rp
# 21  45434905746         WatchEvent    5430309        Dikootje
# 22  45434233341         WatchEvent   54551996       Varun0801
# 23  45432628410          PushEvent    1155738           sh-rp
# 24  45432594395         WatchEvent   11259265        amitbend
# 25  45431808099         WatchEvent    1155738           sh-rp
# 26  45430637689         WatchEvent  118234834    Evgeny-Larin
# 27  45430455123         WatchEvent   42117699    Pablobarbero
# 28  45428131158         WatchEvent   17758284     bilalmaxood
# 29  45422884243         WatchEvent    3732079  rafalkrupinski
#
#    actor__display_login actor__gravatar_id  \
# 0               netlify
# 1            jonbiemond
# 2               netlify
# 3            jonbiemond
# 4            jonbiemond
# 5            jonbiemond
# 6                 yatsu
# 7              weisberg
# 8              weisberg
# 9                 BViki
# 10                BViki
# 11              tmdc-io
# 12            joshklein
# 13             dannyeuu
# 14                sh-rp
# 15                sh-rp
# 16            anhvh1408
# 17            noitcerid
# 18         neuralsignal
# 19             yanchick
# 20                sh-rp
# 21             Dikootje
# 22            Varun0801
# 23                sh-rp
# 24             amitbend
# 25                sh-rp
# 26         Evgeny-Larin
# 27         Pablobarbero
# 28          bilalmaxood
# 29       rafalkrupinski
#
#                                      actor__url  \
# 0     https://api.github.com/users/netlify[bot]
# 1       https://api.github.com/users/jonbiemond
# 2     https://api.github.com/users/netlify[bot]
# 3       https://api.github.com/users/jonbiemond
# 4       https://api.github.com/users/jonbiemond
# 5       https://api.github.com/users/jonbiemond
# 6            https://api.github.com/users/yatsu
# 7         https://api.github.com/users/weisberg
# 8         https://api.github.com/users/weisberg
# 9            https://api.github.com/users/BViki
# 10           https://api.github.com/users/BViki
# 11         https://api.github.com/users/tmdc-io
# 12       https://api.github.com/users/joshklein
# 13        https://api.github.com/users/dannyeuu
# 14           https://api.github.com/users/sh-rp
# 15           https://api.github.com/users/sh-rp
# 16       https://api.github.com/users/anhvh1408
# 17       https://api.github.com/users/noitcerid
# 18    https://api.github.com/users/neuralsignal
# 19        https://api.github.com/users/yanchick
# 20           https://api.github.com/users/sh-rp
# 21        https://api.github.com/users/Dikootje
# 22       https://api.github.com/users/Varun0801
# 23           https://api.github.com/users/sh-rp
# 24        https://api.github.com/users/amitbend
# 25           https://api.github.com/users/sh-rp
# 26    https://api.github.com/users/Evgeny-Larin
# 27    https://api.github.com/users/Pablobarbero
# 28     https://api.github.com/users/bilalmaxood
# 29  https://api.github.com/users/rafalkrupinski
#
#                                     actor__avatar_url   repo__id  \
# 0   https://avatars.githubusercontent.com/u/40209326?  452221115
# 1   https://avatars.githubusercontent.com/u/101326...  452221115
# 2   https://avatars.githubusercontent.com/u/40209326?  452221115
# 3   https://avatars.githubusercontent.com/u/101326...  452221115
# 4   https://avatars.githubusercontent.com/u/101326...  452221115
# 5   https://avatars.githubusercontent.com/u/101326...  452221115
# 6      https://avatars.githubusercontent.com/u/14818?  452221115
# 7    https://avatars.githubusercontent.com/u/5054710?  452221115
# 8    https://avatars.githubusercontent.com/u/5054710?  452221115
# 9    https://avatars.githubusercontent.com/u/6351623?  452221115
# 10   https://avatars.githubusercontent.com/u/6351623?  452221115
# 11  https://avatars.githubusercontent.com/u/73990893?  452221115
# 12    https://avatars.githubusercontent.com/u/251088?  452221115
# 13   https://avatars.githubusercontent.com/u/6808348?  452221115
# 14   https://avatars.githubusercontent.com/u/1155738?  452221115
# 15   https://avatars.githubusercontent.com/u/1155738?  452221115
# 16  https://avatars.githubusercontent.com/u/65499149?  452221115
# 17   https://avatars.githubusercontent.com/u/2380200?  817187285
# 18  https://avatars.githubusercontent.com/u/15611560?  452221115
# 19   https://avatars.githubusercontent.com/u/4449383?  452221115
# 20   https://avatars.githubusercontent.com/u/1155738?  452221115
# 21   https://avatars.githubusercontent.com/u/5430309?  452221115
# 22  https://avatars.githubusercontent.com/u/54551996?  452221115
# 23   https://avatars.githubusercontent.com/u/1155738?  452221115
# 24  https://avatars.githubusercontent.com/u/11259265?  452221115
# 25   https://avatars.githubusercontent.com/u/1155738?  452221115
# 26  https://avatars.githubusercontent.com/u/118234...  452221115
# 27  https://avatars.githubusercontent.com/u/42117699?  817187285
# 28  https://avatars.githubusercontent.com/u/17758284?  817187285
# 29   https://avatars.githubusercontent.com/u/3732079?  452221115
#
#                   repo__name  ... payload__pull_request__head__repo__language  \
# 0                dlt-hub/dlt  ...                                        None
# 1                dlt-hub/dlt  ...                                        None
# 2                dlt-hub/dlt  ...                                        None
# 3                dlt-hub/dlt  ...                                        None
# 4                dlt-hub/dlt  ...                                        None
# 5                dlt-hub/dlt  ...                                        None
# 6                dlt-hub/dlt  ...                                        None
# 7                dlt-hub/dlt  ...                                        None
# 8                dlt-hub/dlt  ...                                        None
# 9                dlt-hub/dlt  ...                                        None
# 10               dlt-hub/dlt  ...                                        None
# 11               dlt-hub/dlt  ...                                        None
# 12               dlt-hub/dlt  ...                                        None
# 13               dlt-hub/dlt  ...                                        None
# 14               dlt-hub/dlt  ...                                        None
# 15               dlt-hub/dlt  ...                                      Python
# 16               dlt-hub/dlt  ...                                        None
# 17  dlt-hub/dlthub-education  ...                                        None
# 18               dlt-hub/dlt  ...                                        None
# 19               dlt-hub/dlt  ...                                        None
# 20               dlt-hub/dlt  ...                                        None
# 21               dlt-hub/dlt  ...                                        None
# 22               dlt-hub/dlt  ...                                        None
# 23               dlt-hub/dlt  ...                                        None
# 24               dlt-hub/dlt  ...                                        None
# 25               dlt-hub/dlt  ...                                        None
# 26               dlt-hub/dlt  ...                                        None
# 27  dlt-hub/dlthub-education  ...                                        None
# 28  dlt-hub/dlthub-education  ...                                        None
# 29               dlt-hub/dlt  ...                                        None
#
#    payload__pull_request__mergeable payload__pull_request__rebaseable  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
# 5                               NaN                               NaN
# 6                               NaN                               NaN
# 7                               NaN                               NaN
# 8                               NaN                               NaN
# 9                               NaN                               NaN
# 10                              NaN                               NaN
# 11                              NaN                               NaN
# 12                              NaN                               NaN
# 13                              NaN                               NaN
# 14                              NaN                               NaN
# 15                             True                             False
# 16                              NaN                               NaN
# 17                              NaN                               NaN
# 18                              NaN                               NaN
# 19                              NaN                               NaN
# 20                              NaN                               NaN
# 21                              NaN                               NaN
# 22                              NaN                               NaN
# 23                              NaN                               NaN
# 24                              NaN                               NaN
# 25                              NaN                               NaN
# 26                              NaN                               NaN
# 27                              NaN                               NaN
# 28                              NaN                               NaN
# 29                              NaN                               NaN
#
#    payload__repository_id payload__push_id payload__size  \
# 0                     NaN              NaN           NaN
# 1                     NaN              NaN           NaN
# 2                     NaN              NaN           NaN
# 3                     NaN              NaN           NaN
# 4                     NaN              NaN           NaN
# 5                     NaN              NaN           NaN
# 6                     NaN              NaN           NaN
# 7                     NaN              NaN           NaN
# 8                     NaN              NaN           NaN
# 9                     NaN              NaN           NaN
# 10                    NaN              NaN           NaN
# 11                    NaN              NaN           NaN
# 12                    NaN              NaN           NaN
# 13                    NaN              NaN           NaN
# 14                    NaN              NaN           NaN
# 15                    NaN              NaN           NaN
# 16                    NaN              NaN           NaN
# 17                    NaN              NaN           NaN
# 18                    NaN              NaN           NaN
# 19                    NaN              NaN           NaN
# 20                    NaN              NaN           NaN
# 21                    NaN              NaN           NaN
# 22                    NaN              NaN           NaN
# 23            452221115.0     2.205999e+10           1.0
# 24                    NaN              NaN           NaN
# 25                    NaN              NaN           NaN
# 26                    NaN              NaN           NaN
# 27                    NaN              NaN           NaN
# 28                    NaN              NaN           NaN
# 29                    NaN              NaN           NaN
#
#    payload__distinct_size                     payload__ref  \
# 0                     NaN                             None
# 1                     NaN                             None
# 2                     NaN                             None
# 3                     NaN                             None
# 4                     NaN                             None
# 5                     NaN                             None
# 6                     NaN                             None
# 7                     NaN                             None
# 8                     NaN                             None
# 9                     NaN                             None
# 10                    NaN                             None
# 11                    NaN                             None
# 12                    NaN                             None
# 13                    NaN                             None
# 14                    NaN                             None
# 15                    NaN                             None
# 16                    NaN                             None
# 17                    NaN                             None
# 18                    NaN                             None
# 19                    NaN                             None
# 20                    NaN                             None
# 21                    NaN                             None
# 22                    NaN                             None
# 23                    1.0  refs/heads/tmp/test_py_versions
# 24                    NaN                             None
# 25                    NaN                             None
# 26                    NaN                             None
# 27                    NaN                             None
# 28                    NaN                             None
# 29                    NaN                             None
#
#                                payload__head  \
# 0                                       None
# 1                                       None
# 2                                       None
# 3                                       None
# 4                                       None
# 5                                       None
# 6                                       None
# 7                                       None
# 8                                       None
# 9                                       None
# 10                                      None
# 11                                      None
# 12                                      None
# 13                                      None
# 14                                      None
# 15                                      None
# 16                                      None
# 17                                      None
# 18                                      None
# 19                                      None
# 20                                      None
# 21                                      None
# 22                                      None
# 23  391785c8338142d4df9c6f37ab632e41362d6046
# 24                                      None
# 25                                      None
# 26                                      None
# 27                                      None
# 28                                      None
# 29                                      None
#
#                              payload__before
# 0                                       None
# 1                                       None
# 2                                       None
# 3                                       None
# 4                                       None
# 5                                       None
# 6                                       None
# 7                                       None
# 8                                       None
# 9                                       None
# 10                                      None
# 11                                      None
# 12                                      None
# 13                                      None
# 14                                      None
# 15                                      None
# 16                                      None
# 17                                      None
# 18                                      None
# 19                                      None
# 20                                      None
# 21                                      None
# 22                                      None
# 23  9c8c86d01285709e4b8f1c53b2e44352ca14eea9
# 24                                      None
# 25                                      None
# 26                                      None
# 27                                      None
# 28                                      None
# 29                                      None
#
# [30 rows x 591 columns]

# %% [markdown]
# You could notice that we received only 1 page, only 30 records. But this endpoint has muuuch more records in total. To get all the pages you should use a pagination.
#
# When working with APIs like GitHub, data is often returned in pages. Pagination allows you to retrieve all the data when an endpoint limits how much can be fetched at once.

# %% [markdown]
# ![1_D9K_aEWo9MDx7osLKT1Cxw.webp](data:image/webp;base64,...)

# %% [markdown]
# ## **Pagination**
#
# GitHub has very good documentation, so it is not difficult to go through the documentation and find the relevant page: [Pagination.](https://docs.github.com/en/rest/using-the-rest-api/using-pagination-in-the-rest-api?apiVersion=2022-11-28)
#
# It says:
# >You can use the `link` header from the response to request additional pages of data.
#
# >The link header contains URLs that you can use to fetch additional pages of results. For example, the previous, next, first, and last page of results.

# %% [markdown]
# **GitHub API Pagination example**
#
# The GitHub API provides the `per_page` and `page` query parameters:
#
# * `per_page`: The number of records per page (up to 100).
# * `page`: The page number to retrieve.

# %%
import requests
response = requests.get("https://api.github.com/orgs/dlt-hub/events?per_page=10&page=1")
response.headers
# Out:
# {'Date': 'Sun, 12 Jan 2025 12:11:19 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept,Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"9149997c1489a8b07b493180bbd92f514e80c0a7281a0c5422ee0c3f25182cd0"', 'Last-Modified': 'Sun, 12 Jan 2025 12:05:48 GMT', 'X-Poll-Interval': '60', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/organizations/89419010/events?per_page=10&page=2>; rel="next", <https://api.github.com/organizations/89419010/events?per_page=10&page=30>; rel="last"', 'x-github-api-version-selected': '2022-11-28', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'Server': 'github.com', 'Accept-Ranges': 'bytes', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '58', 'X-RateLimit-Reset': '1736687411', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '2', 'Transfer-Encoding': 'chunked', 'X-GitHub-Request-Id': 'C802:76288:A35BC1B:146A07B3:6783B167'}

# %% [markdown]
# Gotcha! We can see 'Link' in the headers. To get this link we can alternatively use `response.links`:

# %%
import requests
response = requests.get("https://api.github.com/orgs/dlt-hub/events?per_page=10&page=1")
response.links
# Out:
# {'next': {'url': 'https://api.github.com/organizations/89419010/events?per_page=10&page=2',
#   'rel': 'next'},
#  'last': {'url': 'https://api.github.com/organizations/89419010/events?per_page=10&page=30',
#   'rel': 'last'}}

# %% [markdown]
# ### **dlt RESTClient**
#
# The response includes a 'Link' header for navigating to the next page.
# So now we can implement a pagination!
#
# When working with APIs, you could implement pagination using only Python and the requests library. While this approach works, it often requires writing boilerplate code for tasks like managing authentication, constructing URLs, and handling pagination logic.
#
# More about how to build pagination with Python and `requests`:
#
# * [Link 1](https://farnamdata.com/api-pagination)
#
# * [Link 2](https://www.klamp.io/blog/python-requests-pagination-for-efficient-data-retrieval)
#
# **But!** In this lesson, we’re gonna use dlt's **[RESTClient](https://dlthub.com/docs/general-usage/http/rest-client)** to handle pagination seamlessly when working with REST APIs like GitHub.
#
#
# **Why use RESTClient?**
#
# RESTClient is part of dlt's helpers, making it easier to interact with REST APIs by managing repetitive tasks such as:
#
# * Authentication
# * Query parameter handling
# * Pagination
#
# This reduces boilerplate code and lets you focus on your data pipeline logic.
#
# **Here’s how to fetch paginated data:**
# 1. Import RESTClient
# 2. Create the RESTClient instance
# 3. Use the `paginate` method to iterate through all pages of data.

# %%
from dlt.sources.helpers.rest_client import RESTClient


client = RESTClient(
    base_url="https://api.github.com",
)

for page in client.paginate("orgs/dlt-hub/events"):
    print(page)
# Out:
# [{'id': '45107141128', 'type': 'WatchEvent', 'actor': {'id': 27430, 'login': 'erg', 'display_login': 'erg', 'gravatar_id': '', 'url': 'https://api.github.com/users/erg', 'avatar_url': 'https://avatars.githubusercontent.com/u/27430?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2024-12-27T05:32:29Z', 'org': {'id': 89419010, 'login': 'dlt-hub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/dlt-hub', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?'}}, {'id': '45105877811', 'type': 'WatchEvent', 'actor': {'id': 71960985, 'login': 'karuniaperjuangan', 'display_login': 'karuniaperjuangan', 'gravatar_id': '', 'url': 'https://api.github.com/users/karuniaperjuangan', 'avatar_url': 'https://avatars.githubusercontent.com/u/71960985?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2024-12-27T03:41:43Z', 'org': {'id': 89419010, 'login': 'dlt-hub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/dlt-hub', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?'}}, {'id': '45104166203', 'type': 'WatchEvent', 'actor': {'id': 23615357, 'login': 'visionarylab', 'display_login': 'visionarylab', 'gravatar_id': '', 'url': 'https://api.github.com/users/visionarylab', 'avatar_url': 'https://avatars.githubusercontent.com/u/23615357?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2024-12-27T01:06:28Z', 'org': {'id': 89419010, 'login': 'dlt-hub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/dlt-hub', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?'}}, {'id': '45101707649', 'type': 'WatchEvent', 'actor': {'id': 38707787, 'login': 'SissiFeng', 'display_login': 'SissiFeng', 'gravatar_id': '', 'url': 'https://api.github.com/users/SissiFeng', 'avatar_url': 'https://avatars.githubusercontent.com/u/38707787?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2024-12-26T20:58:54Z', 'org': {'id': 89419010, 'login': 'dlt-hub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/dlt-hub', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?'}}, {'id': '45100801617', 'type': 'WatchEvent', 'actor': {'id': 49382315, 'login': '0xjimm', 'display_login': '0xjimm', 'gravatar_id': '', 'url': 'https://api.github.com/users/0xjimm', 'avatar_url': 'https://avatars.githubusercontent.com/u/49382315?'}, 'repo': {'id': 817187285, 'name': 'dlt-hub/dlthub-education', 'url': 'https://api.github.com/repos/dlt-hub/dlthub-education'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2024-12-26T19:45:54Z', 'org': {'id': 89419010, 'login': 'dlt-hub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/dlt-hub', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?'}}, {'id': '45099468903', 'type': 'WatchEvent', 'actor': {'id': 70040554, 'login': 'theDataFixer', 'display_login': 'theDataFixer', 'gravatar_id': '', 'url': 'https://api.github.com/users/theDataFixer', 'avatar_url': 'https://avatars.githubusercontent.com/u/70040554?'}, 'repo': {'id': 717056013, 'name': 'dlt-hub/dlt-kestra-demo', 'url': 'https://api.github.com/repos/dlt-hub/dlt-kestra-demo'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2024-12-26T18:07:39Z', 'org': {'id': 89419010, 'login': 'dlt-hub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/dlt-hub', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?'}}, {'id': '45098624424', 'type': 'WatchEvent', 'actor': {'id': 51961452, 'login': 'hansri', 'display_login': 'hansri', 'gravatar_id': '', 'url': 'https://api.github.com/users/hansri', 'avatar_u ...
# [{'id': '45046565400', 'type': 'IssuesEvent', 'actor': {'id': 23084949, 'login': 'trymzet', 'display_login': 'trymzet', 'gravatar_id': '', 'url': 'https://api.github.com/users/trymzet', 'avatar_url': 'https://avatars.githubusercontent.com/u/23084949?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'opened', 'issue': {'url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2178', 'repository_url': 'https://api.github.com/repos/dlt-hub/dlt', 'labels_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2178/labels{/name}', 'comments_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2178/comments', 'events_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2178/events', 'html_url': 'https://github.com/dlt-hub/dlt/issues/2178', 'id': 2756746330, 'node_id': 'I_kwDOGvRYu86kUJxa', 'number': 2178, 'title': '`Pipeline.dataset()` fails if `ibis` is not installed', 'user': {'login': 'trymzet', 'id': 23084949, 'node_id': 'MDQ6VXNlcjIzMDg0OTQ5', 'avatar_url': 'https://avatars.githubusercontent.com/u/23084949?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/trymzet', 'html_url': 'https://github.com/trymzet', 'followers_url': 'https://api.github.com/users/trymzet/followers', 'following_url': 'https://api.github.com/users/trymzet/following{/other_user}', 'gists_url': 'https://api.github.com/users/trymzet/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/trymzet/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/trymzet/subscriptions', 'organizations_url': 'https://api.github.com/users/trymzet/orgs', 'repos_url': 'https://api.github.com/users/trymzet/repos', 'events_url': 'https://api.github.com/users/trymzet/events{/privacy}', 'received_events_url': 'https://api.github.com/users/trymzet/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'labels': [], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 0, 'created_at': '2024-12-23T21:37:57Z', 'updated_at': '2024-12-23T21:37:57Z', 'closed_at': None, 'author_association': 'CONTRIBUTOR', 'active_lock_reason': None, 'body': '### dlt version\n\n1.5.0\n\n### Describe the problem\n\nAccording to the docstring, the method should fall back to a dbapi interface if the default value of `dataset_type` (`"auto"`) is used. However, it fails with an `ImportError`.\r\n\r\nProbably why the example in the first notebook in the dbt fundamentals course explicitly sets the value of this param to `"default"`?\n\n### Expected behavior\n\n_No response_\n\n### Steps to reproduce\n\n```python\r\n# !pip install "dlt[duckdb]"\r\n\r\nimport dlt\r\n\r\ndata = [\r\n    {"id": "1", "name": "bulbasaur", "size": {"weight": 6.9, "height": 0.7}},\r\n    {"id": "4", "name": "charmander", "size": {"weight": 8.5, "height": 0.6}},\r\n    {"id": "25", "name": "pikachu", "size": {"weight": 6, "height": 0.4}},\r\n]\r\npipeline = dlt.pipeline(\r\n    pipeline_name="quick_start",\r\n    destination="duckdb",\r\n    dataset_name="mydata",\r\n)\r\npipeline.run(data, table_name="pokemon")\r\n\r\ndataset = pipeline.dataset()\r\ndf = dataset.pokemon.df()\r\n```\n\n### Operating system\n\nLinux\n\n### Runtime environment\n\nGoogle Colab\n\n### Python version\n\n3.11\n\n### dlt data source\n\n_No response_\n\n### dlt destination\n\n_No response_\n\n### Other deployment details\n\n_No response_\n\n### Additional information\n\n```python\r\n---------------------------------------------------------------------------\r\nModuleNotFoundError                       Traceback (most recent call last)\r\n[/usr/local/lib/python3.10/dist-packages/ibis/__init__.py](https://localhost:8080/#) in load_backend(name)\r\n     81     try:\r\n---> 82         module = entry_point.load()\r\n     83     except ImportError as exc:\r\n\r\n16 frames\r\n[/usr/local/lib/python3.10/dist-packages/importlib_metadata/__init__.py](https://localhost:8080/#) in loa ...
# [{'id': '45031686475', 'type': 'PushEvent', 'actor': {'id': 17202864, 'login': 'rudolfix', 'display_login': 'rudolfix', 'gravatar_id': '', 'url': 'https://api.github.com/users/rudolfix', 'avatar_url': 'https://avatars.githubusercontent.com/u/17202864?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'repository_id': 452221115, 'push_id': 21837173947, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/devel', 'head': 'fb17e994baf824cecc6958249f6c488579146606', 'before': '5a1cb69a31ffbe82cf0f00fb65b94e05e7310763', 'commits': [{'sha': 'fb17e994baf824cecc6958249f6c488579146606', 'author': {'email': 'rudolfix@rudolfix.org', 'name': 'rudolfix'}, 'message': 'recognizes ARRAY data type and converts to nested, fixes minimal nested types handling for sqlalchemy backend (#2177)', 'distinct': True, 'url': 'https://api.github.com/repos/dlt-hub/dlt/commits/fb17e994baf824cecc6958249f6c488579146606'}]}, 'public': True, 'created_at': '2024-12-23T10:37:44Z', 'org': {'id': 89419010, 'login': 'dlt-hub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/dlt-hub', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?'}}, {'id': '45031686276', 'type': 'PullRequestEvent', 'actor': {'id': 17202864, 'login': 'rudolfix', 'display_login': 'rudolfix', 'gravatar_id': '', 'url': 'https://api.github.com/users/rudolfix', 'avatar_url': 'https://avatars.githubusercontent.com/u/17202864?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'closed', 'number': 2177, 'pull_request': {'url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2177', 'id': 2248548798, 'node_id': 'PR_kwDOGvRYu86GBiG-', 'html_url': 'https://github.com/dlt-hub/dlt/pull/2177', 'diff_url': 'https://github.com/dlt-hub/dlt/pull/2177.diff', 'patch_url': 'https://github.com/dlt-hub/dlt/pull/2177.patch', 'issue_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2177', 'number': 2177, 'state': 'closed', 'locked': False, 'title': 'recognizes ARRAY data type and converts to nested, fixes minimal nested types handling for sqlalchemy backend', 'user': {'login': 'rudolfix', 'id': 17202864, 'node_id': 'MDQ6VXNlcjE3MjAyODY0', 'avatar_url': 'https://avatars.githubusercontent.com/u/17202864?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/rudolfix', 'html_url': 'https://github.com/rudolfix', 'followers_url': 'https://api.github.com/users/rudolfix/followers', 'following_url': 'https://api.github.com/users/rudolfix/following{/other_user}', 'gists_url': 'https://api.github.com/users/rudolfix/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/rudolfix/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/rudolfix/subscriptions', 'organizations_url': 'https://api.github.com/users/rudolfix/orgs', 'repos_url': 'https://api.github.com/users/rudolfix/repos', 'events_url': 'https://api.github.com/users/rudolfix/events{/privacy}', 'received_events_url': 'https://api.github.com/users/rudolfix/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'body': '<!--\r\nThank you for submitting a pull request! Please provide a brief description of your changes below.\r\n-->\r\n### Description\r\n* recognizes ARRAY data type and converts to nested, fixes minimal nested types handling for sqlalchemy backend\r\n* ports and closes https://github.com/dlt-hub/verified-sources/pull/547 by @vivingo\r\n', 'created_at': '2024-12-22T22:28:51Z', 'updated_at': '2024-12-23T10:37:43Z', 'closed_at': '2024-12-23T10:37:42Z', 'merged_at': '2024-12-23T10:37:42Z', 'merge_commit_sha': 'fb17e994baf824cecc6958249f6c488579146606', 'assignee': None, 'assignees': [], 'requested_reviewers': [], 'requested_teams': [], 'labels': [], 'milestone': None, 'draft': False, 'commits_url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2177/commits', 'review_comments_url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2177/comme ...
# [{'id': '45018115024', 'type': 'CreateEvent', 'actor': {'id': 17202864, 'login': 'rudolfix', 'display_login': 'rudolfix', 'gravatar_id': '', 'url': 'https://api.github.com/users/rudolfix', 'avatar_url': 'https://avatars.githubusercontent.com/u/17202864?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'ref': 'fix/2020-2151-fixes-dbt-arrow', 'ref_type': 'branch', 'master_branch': 'devel', 'description': 'data load tool (dlt) is an open source Python library that makes data loading easy 🛠️ ', 'pusher_type': 'user'}, 'public': True, 'created_at': '2024-12-22T19:37:41Z', 'org': {'id': 89419010, 'login': 'dlt-hub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/dlt-hub', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?'}}, {'id': '45018097646', 'type': 'IssuesEvent', 'actor': {'id': 9097817, 'login': 'HectorBst', 'display_login': 'HectorBst', 'gravatar_id': '', 'url': 'https://api.github.com/users/HectorBst', 'avatar_url': 'https://avatars.githubusercontent.com/u/9097817?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'opened', 'issue': {'url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2174', 'repository_url': 'https://api.github.com/repos/dlt-hub/dlt', 'labels_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2174/labels{/name}', 'comments_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2174/comments', 'events_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2174/events', 'html_url': 'https://github.com/dlt-hub/dlt/issues/2174', 'id': 2754810404, 'node_id': 'I_kwDOGvRYu86kMxIk', 'number': 2174, 'title': 'LangChain / LlamaIndex VectorStore as destination', 'user': {'login': 'HectorBst', 'id': 9097817, 'node_id': 'MDQ6VXNlcjkwOTc4MTc=', 'avatar_url': 'https://avatars.githubusercontent.com/u/9097817?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/HectorBst', 'html_url': 'https://github.com/HectorBst', 'followers_url': 'https://api.github.com/users/HectorBst/followers', 'following_url': 'https://api.github.com/users/HectorBst/following{/other_user}', 'gists_url': 'https://api.github.com/users/HectorBst/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/HectorBst/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/HectorBst/subscriptions', 'organizations_url': 'https://api.github.com/users/HectorBst/orgs', 'repos_url': 'https://api.github.com/users/HectorBst/repos', 'events_url': 'https://api.github.com/users/HectorBst/events{/privacy}', 'received_events_url': 'https://api.github.com/users/HectorBst/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'labels': [], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 0, 'created_at': '2024-12-22T19:35:32Z', 'updated_at': '2024-12-22T19:35:32Z', 'closed_at': None, 'author_association': 'NONE', 'active_lock_reason': None, 'body': "### Feature description\n\nLangChain and LlamaIndex are frameworks widely used in the construction of RAG solutions. In particular, they each define an abstract Vector Store interface, implemented for different technologies by themselves or partners.\r\n\r\nAdd a LangChain and a LlamaIndex destinations, based on the abstract interfaces.\n\n### Are you a dlt user?\n\nYes, I'm already a dlt user.\n\n### Use case\n\n- I want to easily load data into an as-yet unsupported Vector Store, using an existing LangChain / LlamaIndex implementation.\r\n- I want to reuse existing LangChain / LlamaIndex code\r\n- I want to use my own LangChain / LlamaIndex connector instead of the existing dlt destination.\r\n- I want to be able to switch easily from one Vector Store to another (e.g. for local testing or future architecture changes).\n\n### Proposed solution\n\nA LangChainVectorStore destination and a LlamaIndexVectorStore destination, based on the abstract  ...
# [{'id': '44972992629', 'type': 'WatchEvent', 'actor': {'id': 10026538, 'login': 'connorads', 'display_login': 'connorads', 'gravatar_id': '', 'url': 'https://api.github.com/users/connorads', 'avatar_url': 'https://avatars.githubusercontent.com/u/10026538?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2024-12-20T07:56:49Z', 'org': {'id': 89419010, 'login': 'dlt-hub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/dlt-hub', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?'}}, {'id': '44972985670', 'type': 'WatchEvent', 'actor': {'id': 219098, 'login': 'MrJack91', 'display_login': 'MrJack91', 'gravatar_id': '', 'url': 'https://api.github.com/users/MrJack91', 'avatar_url': 'https://avatars.githubusercontent.com/u/219098?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2024-12-20T07:56:32Z', 'org': {'id': 89419010, 'login': 'dlt-hub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/dlt-hub', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?'}}, {'id': '44971384487', 'type': 'WatchEvent', 'actor': {'id': 15677097, 'login': 'Serpinex3', 'display_login': 'Serpinex3', 'gravatar_id': '', 'url': 'https://api.github.com/users/Serpinex3', 'avatar_url': 'https://avatars.githubusercontent.com/u/15677097?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2024-12-20T06:43:53Z', 'org': {'id': 89419010, 'login': 'dlt-hub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/dlt-hub', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?'}}, {'id': '44926708707', 'type': 'WatchEvent', 'actor': {'id': 32022475, 'login': 'mathdone', 'display_login': 'mathdone', 'gravatar_id': '', 'url': 'https://api.github.com/users/mathdone', 'avatar_url': 'https://avatars.githubusercontent.com/u/32022475?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2024-12-18T23:47:47Z', 'org': {'id': 89419010, 'login': 'dlt-hub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/dlt-hub', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?'}}, {'id': '44926689238', 'type': 'WatchEvent', 'actor': {'id': 84082646, 'login': 'AmorimEureka', 'display_login': 'AmorimEureka', 'gravatar_id': '', 'url': 'https://api.github.com/users/AmorimEureka', 'avatar_url': 'https://avatars.githubusercontent.com/u/84082646?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2024-12-18T23:46:38Z', 'org': {'id': 89419010, 'login': 'dlt-hub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/dlt-hub', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?'}}, {'id': '44926657688', 'type': 'WatchEvent', 'actor': {'id': 84082646, 'login': 'AmorimEureka', 'display_login': 'AmorimEureka', 'gravatar_id': '', 'url': 'https://api.github.com/users/AmorimEureka', 'avatar_url': 'https://avatars.githubusercontent.com/u/84082646?'}, 'repo': {'id': 817187285, 'name': 'dlt-hub/dlthub-education', 'url': 'https://api.github.com/repos/dlt-hub/dlthub-education'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2024-12-18T23:44:46Z', 'org': {'id': 89419010, 'login': 'dlt-hub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/dlt-hub', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?'}}, {'id': '44923647297', 'type': 'PushEvent', 'actor': {'id': 1155738, 'login': 'sh-rp', 'display_login': 'sh-rp', 'gravatar_id': '', 'url': 'https://api.github.com/users/sh-rp', 'avatar_url': 'https://avatars.githubus ...
# [{'id': '44906180846', 'type': 'IssueCommentEvent', 'actor': {'id': 188038, 'login': 'joscha', 'display_login': 'joscha', 'gravatar_id': '', 'url': 'https://api.github.com/users/joscha', 'avatar_url': 'https://avatars.githubusercontent.com/u/188038?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'created', 'issue': {'url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2083', 'repository_url': 'https://api.github.com/repos/dlt-hub/dlt', 'labels_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2083/labels{/name}', 'comments_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2083/comments', 'events_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2083/events', 'html_url': 'https://github.com/dlt-hub/dlt/pull/2083', 'id': 2679200513, 'node_id': 'PR_kwDOGvRYu86Cp_zK', 'number': 2083, 'title': 'chore: devenv environment', 'user': {'login': 'joscha', 'id': 188038, 'node_id': 'MDQ6VXNlcjE4ODAzOA==', 'avatar_url': 'https://avatars.githubusercontent.com/u/188038?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/joscha', 'html_url': 'https://github.com/joscha', 'followers_url': 'https://api.github.com/users/joscha/followers', 'following_url': 'https://api.github.com/users/joscha/following{/other_user}', 'gists_url': 'https://api.github.com/users/joscha/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/joscha/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/joscha/subscriptions', 'organizations_url': 'https://api.github.com/users/joscha/orgs', 'repos_url': 'https://api.github.com/users/joscha/repos', 'events_url': 'https://api.github.com/users/joscha/events{/privacy}', 'received_events_url': 'https://api.github.com/users/joscha/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'labels': [], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 3, 'created_at': '2024-11-21T11:49:13Z', 'updated_at': '2024-12-18T12:26:45Z', 'closed_at': None, 'author_association': 'CONTRIBUTOR', 'active_lock_reason': None, 'draft': False, 'pull_request': {'url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2083', 'html_url': 'https://github.com/dlt-hub/dlt/pull/2083', 'diff_url': 'https://github.com/dlt-hub/dlt/pull/2083.diff', 'patch_url': 'https://github.com/dlt-hub/dlt/pull/2083.patch', 'merged_at': None}, 'body': '<!--\r\nThank you for submitting a pull request! Please provide a brief description of your changes below.\r\n-->\r\n### Description\r\n\r\nThis adds a [Devenv](https://devenv.sh/) environment to the repository which allows immediate development w/o have to worry about local installation of dependencies (make, python, poetry, etc.).\r\nDevenv is using [`nix`](https://nix.dev/index.html) under the hood, which provides a reproducible environment due to the fact that it controls the whole dependency closure. That means that the files in this PR would ensure that all developers would use the same version of make, python, poetry, etc. for their local development of dlt, which reduces a whole bunch of problems when talking about issues, opening pull requests, etc.\r\n\r\nIf the system has `direnv` and `devenv` installed everything is automatic.\r\nAfter activating the environment, `setup` can be run, which calls out to `make dev`.\r\n\r\nAlso happy to swap this for a raw [nix flake](https://nixos.wiki/wiki/Flakes) or even a [nix-shell](https://nixos.wiki/wiki/Development_environment_with_nix-shell) if devenv is too bleeding edge.', 'reactions': {'url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2083/reactions', 'total_count': 0, '+1': 0, '-1': 0, 'laugh': 0, 'hooray': 0, 'confused': 0, 'heart': 0, 'rocket': 0, 'eyes': 0}, 'timeline_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2083/timeline', 'performed_via_github_app': None, 'state_reason': None}, 'comment': {'url': 'https://api.github.com/repos/dlt-hub/dl ...
# [{'id': '44874042718', 'type': 'PullRequestReviewCommentEvent', 'actor': {'id': 188038, 'login': 'joscha', 'display_login': 'joscha', 'gravatar_id': '', 'url': 'https://api.github.com/users/joscha', 'avatar_url': 'https://avatars.githubusercontent.com/u/188038?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'created', 'comment': {'url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/comments/1888762191', 'pull_request_review_id': 2509293796, 'id': 1888762191, 'node_id': 'PRRC_kwDOGvRYu85wlDlP', 'diff_hunk': '@@ -693,3 +693,30 @@ for page in client.paginate(\n ):\n     print(page)\n ```\n+\n+## Performance\n+\n+If you have a substantial amount of requests going to a single or smaller set of hosts, it can be worth to use connection pooling.\n+You can do this by leveraging the custom `session` parameter like so:\n+\n+```py\n+from dlt.sources.helpers.rest_client.client import RESTClient\n+from dlt.sources.helpers.requests.session import Session\n+from requests.adapters import HTTPAdapter\n+\n+base_url = "https://api.my-service.com"\n+\n+session = Session(raise_for_status=False)\n+adapter = HTTPAdapter(\n+    # We\'re only using one host for all requests in our example\n+    pool_connections=1,\n+    # But we\'re making a lot of requests and want to reuse connections\n+    pool_maxsize=100,\n+)\n+session.mount(api_base, adapter)', 'path': 'docs/website/docs/general-usage/http/rest-client.md', 'commit_id': 'a53c91157edc86f521d9dea81f943f407875eb43', 'original_commit_id': 'a53c91157edc86f521d9dea81f943f407875eb43', 'user': {'login': 'joscha', 'id': 188038, 'node_id': 'MDQ6VXNlcjE4ODAzOA==', 'avatar_url': 'https://avatars.githubusercontent.com/u/188038?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/joscha', 'html_url': 'https://github.com/joscha', 'followers_url': 'https://api.github.com/users/joscha/followers', 'following_url': 'https://api.github.com/users/joscha/following{/other_user}', 'gists_url': 'https://api.github.com/users/joscha/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/joscha/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/joscha/subscriptions', 'organizations_url': 'https://api.github.com/users/joscha/orgs', 'repos_url': 'https://api.github.com/users/joscha/repos', 'events_url': 'https://api.github.com/users/joscha/events{/privacy}', 'received_events_url': 'https://api.github.com/users/joscha/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'body': '```suggestion\r\nsession.mount(base_url, adapter)\r\n```', 'created_at': '2024-12-17T15:55:55Z', 'updated_at': '2024-12-17T15:55:56Z', 'html_url': 'https://github.com/dlt-hub/dlt/pull/2160#discussion_r1888762191', 'pull_request_url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2160', 'author_association': 'CONTRIBUTOR', '_links': {'self': {'href': 'https://api.github.com/repos/dlt-hub/dlt/pulls/comments/1888762191'}, 'html': {'href': 'https://github.com/dlt-hub/dlt/pull/2160#discussion_r1888762191'}, 'pull_request': {'href': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2160'}}, 'reactions': {'url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/comments/1888762191/reactions', 'total_count': 0, '+1': 0, '-1': 0, 'laugh': 0, 'hooray': 0, 'confused': 0, 'heart': 0, 'rocket': 0, 'eyes': 0}, 'start_line': None, 'original_start_line': None, 'start_side': None, 'line': 716, 'original_line': 716, 'side': 'RIGHT', 'original_position': 24, 'position': 24, 'subject_type': 'line'}, 'pull_request': {'url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2160', 'id': 2239990626, 'node_id': 'PR_kwDOGvRYu86Fg4ti', 'html_url': 'https://github.com/dlt-hub/dlt/pull/2160', 'diff_url': 'https://github.com/dlt-hub/dlt/pull/2160.diff', 'patch_url': 'https://github.com/dlt-hub/dlt/pull/2160.patch', 'issue_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2160', 'number': 2160, 'state': 'open', 'locked': False, 't ...
# [{'id': '44866112569', 'type': 'IssueCommentEvent', 'actor': {'id': 40209326, 'login': 'netlify[bot]', 'display_login': 'netlify', 'gravatar_id': '', 'url': 'https://api.github.com/users/netlify[bot]', 'avatar_url': 'https://avatars.githubusercontent.com/u/40209326?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'created', 'issue': {'url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2157', 'repository_url': 'https://api.github.com/repos/dlt-hub/dlt', 'labels_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2157/labels{/name}', 'comments_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2157/comments', 'events_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2157/events', 'html_url': 'https://github.com/dlt-hub/dlt/pull/2157', 'id': 2744814466, 'node_id': 'PR_kwDOGvRYu86FfMX9', 'number': 2157, 'title': 'disconnect ibis backend after running ibis tests', 'user': {'login': 'sh-rp', 'id': 1155738, 'node_id': 'MDQ6VXNlcjExNTU3Mzg=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1155738?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/sh-rp', 'html_url': 'https://github.com/sh-rp', 'followers_url': 'https://api.github.com/users/sh-rp/followers', 'following_url': 'https://api.github.com/users/sh-rp/following{/other_user}', 'gists_url': 'https://api.github.com/users/sh-rp/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/sh-rp/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/sh-rp/subscriptions', 'organizations_url': 'https://api.github.com/users/sh-rp/orgs', 'repos_url': 'https://api.github.com/users/sh-rp/repos', 'events_url': 'https://api.github.com/users/sh-rp/events{/privacy}', 'received_events_url': 'https://api.github.com/users/sh-rp/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'labels': [], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 1, 'created_at': '2024-12-17T12:30:59Z', 'updated_at': '2024-12-17T12:31:20Z', 'closed_at': None, 'author_association': 'COLLABORATOR', 'active_lock_reason': None, 'draft': False, 'pull_request': {'url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2157', 'html_url': 'https://github.com/dlt-hub/dlt/pull/2157', 'diff_url': 'https://github.com/dlt-hub/dlt/pull/2157.diff', 'patch_url': 'https://github.com/dlt-hub/dlt/pull/2157.patch', 'merged_at': None}, 'body': '<!--\r\nThank you for submitting a pull request! Please provide a brief description of your changes below.\r\n-->\r\n### Description\r\n', 'reactions': {'url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2157/reactions', 'total_count': 0, '+1': 0, '-1': 0, 'laugh': 0, 'hooray': 0, 'confused': 0, 'heart': 0, 'rocket': 0, 'eyes': 0}, 'timeline_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2157/timeline', 'performed_via_github_app': None, 'state_reason': None}, 'comment': {'url': 'https://api.github.com/repos/dlt-hub/dlt/issues/comments/2548336082', 'html_url': 'https://github.com/dlt-hub/dlt/pull/2157#issuecomment-2548336082', 'issue_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2157', 'id': 2548336082, 'node_id': 'IC_kwDOGvRYu86X5IXS', 'user': {'login': 'netlify[bot]', 'id': 40209326, 'node_id': 'MDM6Qm90NDAyMDkzMjY=', 'avatar_url': 'https://avatars.githubusercontent.com/in/13473?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/netlify%5Bbot%5D', 'html_url': 'https://github.com/apps/netlify', 'followers_url': 'https://api.github.com/users/netlify%5Bbot%5D/followers', 'following_url': 'https://api.github.com/users/netlify%5Bbot%5D/following{/other_user}', 'gists_url': 'https://api.github.com/users/netlify%5Bbot%5D/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/netlify%5Bbot%5D/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/netlify%5Bbot%5D/subscriptions', 'organizations_url': 'https://api.github.com/users/ne ...
# [{'id': '44857937779', 'type': 'PullRequestReviewEvent', 'actor': {'id': 28436330, 'login': 'donotpush', 'display_login': 'donotpush', 'gravatar_id': '', 'url': 'https://api.github.com/users/donotpush', 'avatar_url': 'https://avatars.githubusercontent.com/u/28436330?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'created', 'review': {'id': 2508188035, 'node_id': 'PRR_kwDOGvRYu86Vf-mD', 'user': {'login': 'donotpush', 'id': 28436330, 'node_id': 'MDQ6VXNlcjI4NDM2MzMw', 'avatar_url': 'https://avatars.githubusercontent.com/u/28436330?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/donotpush', 'html_url': 'https://github.com/donotpush', 'followers_url': 'https://api.github.com/users/donotpush/followers', 'following_url': 'https://api.github.com/users/donotpush/following{/other_user}', 'gists_url': 'https://api.github.com/users/donotpush/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/donotpush/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/donotpush/subscriptions', 'organizations_url': 'https://api.github.com/users/donotpush/orgs', 'repos_url': 'https://api.github.com/users/donotpush/repos', 'events_url': 'https://api.github.com/users/donotpush/events{/privacy}', 'received_events_url': 'https://api.github.com/users/donotpush/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'body': 'LGTM', 'commit_id': 'f55cfe8ab1e0b03c46770201ca67479193c49b4e', 'submitted_at': '2024-12-17T08:39:49Z', 'state': 'approved', 'html_url': 'https://github.com/dlt-hub/dlt/pull/2153#pullrequestreview-2508188035', 'pull_request_url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2153', 'author_association': 'COLLABORATOR', '_links': {'html': {'href': 'https://github.com/dlt-hub/dlt/pull/2153#pullrequestreview-2508188035'}, 'pull_request': {'href': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2153'}}}, 'pull_request': {'url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2153', 'id': 2237713573, 'node_id': 'PR_kwDOGvRYu86FYMyl', 'html_url': 'https://github.com/dlt-hub/dlt/pull/2153', 'diff_url': 'https://github.com/dlt-hub/dlt/pull/2153.diff', 'patch_url': 'https://github.com/dlt-hub/dlt/pull/2153.patch', 'issue_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2153', 'number': 2153, 'state': 'open', 'locked': False, 'title': 'Update auth info in databricks docs', 'user': {'login': 'VioletM', 'id': 9139429, 'node_id': 'MDQ6VXNlcjkxMzk0Mjk=', 'avatar_url': 'https://avatars.githubusercontent.com/u/9139429?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/VioletM', 'html_url': 'https://github.com/VioletM', 'followers_url': 'https://api.github.com/users/VioletM/followers', 'following_url': 'https://api.github.com/users/VioletM/following{/other_user}', 'gists_url': 'https://api.github.com/users/VioletM/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/VioletM/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/VioletM/subscriptions', 'organizations_url': 'https://api.github.com/users/VioletM/orgs', 'repos_url': 'https://api.github.com/users/VioletM/repos', 'events_url': 'https://api.github.com/users/VioletM/events{/privacy}', 'received_events_url': 'https://api.github.com/users/VioletM/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'body': None, 'created_at': '2024-12-16T16:02:06Z', 'updated_at': '2024-12-17T08:39:49Z', 'closed_at': None, 'merged_at': None, 'merge_commit_sha': '068f3a27ef43fbdc8ac03ebf8c4f056dc16a7e43', 'assignee': None, 'assignees': [], 'requested_reviewers': [], 'requested_teams': [], 'labels': [], 'milestone': None, 'draft': False, 'commits_url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2153/commits', 'review_comments_url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2153/comments', 'review_comment_url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/comments{/number} ...
# [{'id': '44835828532', 'type': 'PullRequestReviewCommentEvent', 'actor': {'id': 9139429, 'login': 'VioletM', 'display_login': 'VioletM', 'gravatar_id': '', 'url': 'https://api.github.com/users/VioletM', 'avatar_url': 'https://avatars.githubusercontent.com/u/9139429?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'created', 'comment': {'url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/comments/1887170583', 'pull_request_review_id': 2506745618, 'id': 1887170583, 'node_id': 'PRRC_kwDOGvRYu85we_AX', 'diff_hunk': '@@ -6,33 +6,47 @@ keywords: [architecture, extract, normalize, load]\n \n # How `dlt` works\n \n-`dlt` automatically turns JSON returned by any [source](../../general-usage/glossary.md#source)\n-(e.g., an API) into a live dataset stored in the\n-[destination](../../general-usage/glossary.md#destination) of your choice (e.g., Google BigQuery). It\n-does this by first [extracting](how-dlt-works.md#extract) the JSON data, then\n-[normalizing](how-dlt-works.md#normalize) it to a schema, and finally [loading](how-dlt-works#load)\n-it to the location where you will store it.\n+In a nutshell, `dlt` automatically turns data from a number of available [sources](../../general-usage/source) (e.g., an API, a PostgreSQL database, or Python data structures) into a live dataset stored in a [destination](../../general-usage/destination) of your choice (e.g., Google BigQuery, a Deltalake on Azure, or by pushing the data back via reverse ETL). You can easily implement your own sources, as long as you yield data in a way that is compatible with `dlt`, such as JSON objects, Python lists and dictionaries, pandas dataframes, and arrow tables. `dlt` will be able to automatically compute the schema and move the data to your destination.\n \n-![architecture-diagram](/img/architecture-diagram.png)\n+![architecture-diagram](/img/dlt-onepager.svg)\n \n-## Extract\n+## A concrete example\n \n-The Python script requests data from an API or a similar\n-[source](../../general-usage/glossary.md#source). Once this data is received, the script parses the\n-JSON and provides it to `dlt` as input, which then normalizes that data.\n+The main building block of `dlt` is the [pipeline](../../general-usage/glossary.md#pipeline), which orchestrates the loading of data from your source into your destination in three discrete steps when you call its `run` method. Consider this intentionally short example:\n \n-## Normalize\n+```py\n+import dlt\n \n-The configurable normalization engine in `dlt` recursively unpacks this nested structure into\n-relational tables (i.e., inferring data types, linking tables to create nested relationships,\n-etc.), making it ready to be loaded. This creates a\n-[schema](../../general-usage/glossary.md#schema), which will automatically evolve to accommodate any future\n-source data changes (e.g., new fields or tables).\n+pipeline = dlt.pipeline(pipeline_name="my_pipeline", destination="duckdb")\n+pipeline.run([{"id": 1}, {"id": 2}, {"id": 3}], table_name="items")\n+```\n \n-## Load\n+This is what happens when the `run` method is executed:\n \n-The data is then loaded into your chosen [destination](../../general-usage/glossary.md#destination).\n-`dlt` uses configurable, idempotent, atomic loads that ensure data safely ends up there. For\n-example, you don\'t need to worry about the size of the data you are loading, and if the process is\n-interrupted, it is safe to retry without creating errors.\n+1. [Extract](how-dlt-works.md#extract) - Fully extracts the data from your source to your hard drive. In the example above, an implicit source with one resource with 3 items is created and extracted.\n+2. [Normalize](how-dlt-works.md#normalize) - Inspects and normalizes your data and computes a schema compatible with your destination. For the example above, the normalizer will detect one column `id` of type `int` in one table named `items` and no further normaliza ...

# %% [markdown]
# Pagination type was detected automatically, but you can explicitly provide it:

# %%
from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.paginators import HeaderLinkPaginator

client = RESTClient(
    base_url="https://api.github.com",
    paginator=HeaderLinkPaginator(),
)

# %%
print(client)
# Out:
# <dlt.sources.helpers.rest_client.client.RESTClient object at 0x7d5530e7beb0>

# %% [markdown]
# The full list of available paginators you can see in offcial [dlt documentation](https://dlthub.com/docs/general-usage/http/rest-client#paginators).

# %% [markdown]
# ![Screenshot 2024-12-13 at 16.09.04.png](data:image/png;base64,...)

# %% [markdown]
# Endpoint events has not so much data as for example enpoint stargazers for dlt repo. If you run the pipeline for endpoint stargazers, there is a high chance that you face the **rate limit error**.

# %%
from dlt.sources.helpers.rest_client import RESTClient


client = RESTClient(
    base_url="https://api.github.com",
)

for page in client.paginate("repos/dlt-hub/dlt/stargazers"):
    print(page)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-3-9b37d2b2fdbc> in <cell line: 8>()
#       6 )
#       7
# ----> 8 for page in client.paginate("repos/dlt-hub/dlt/stargazers"):
#       9     print(page)
#
# /usr/local/lib/python3.10/dist-packages/dlt/sources/helpers/rest_client/client.py in paginate(self, path, method, params, json, auth, paginator, data_selector, hooks, **kwargs)
#     222         while True:
#     223             try:
# --> 224                 response = self._send_request(request, **kwargs)
#     225             except IgnoreResponseException:
#     226                 break
#
# /usr/local/lib/python3.10/dist-packages/dlt/sources/helpers/rest_client/client.py in _send_request(self, request, **kwargs)
#     138
#     139         send_kwargs.update(**kwargs)  #  type: ignore[call-arg]
# --> 140         return self.session.send(prepared_request, **send_kwargs)
#     141
#     142     def request(self, path: str = "", method: HTTPMethod = "GET", **kwargs: Any) -> Response:
#
# /usr/local/lib/python3.10/dist-packages/tenacity/__init__.py in wrapped_f(*args, **kw)
#     334             copy = self.copy()
#     335             wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 336             return copy(f, *args, **kw)
#     337
#     338         def retry_with(*args: t.Any, **kwargs: t.Any) -> WrappedFn:
#
# /usr/local/lib/python3.10/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     473         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474         while True:
# --> 475             do = self.iter(retry_state=retry_state)
#     476             if isinstance(do, DoAttempt):
#     477                 try:
#
# /usr/local/lib/python3.10/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     374         result = None
#     375         for action in self.iter_state.actions:
# --> 376             result = action(retry_state)
#     377         return result
#     378
#
# /usr/local/lib/python3.10/dist-packages/tenacity/__init__.py in <lambda>(rs)
#     396     def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     397         if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 398             self._add_action_func(lambda rs: rs.outcome.result())
#     399             return
#     400
#
# /usr/lib/python3.10/concurrent/futures/_base.py in result(self, timeout)
#     449                     raise CancelledError()
#     450                 elif self._state == FINISHED:
# --> 451                     return self.__get_result()
#     452
#     453                 self._condition.wait(timeout)
#
# /usr/lib/python3.10/concurrent/futures/_base.py in __get_result(self)
#     401         if self._exception:
#     402             try:
# --> 403                 raise self._exception
#     404             finally:
#     405                 # Break a reference cycle with the exception in self._exception
#
# /usr/local/lib/python3.10/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     476             if isinstance(do, DoAttempt):
#     477                 try:
# --> 478                     result = fn(*args, **kwargs)
#     479                 except BaseException:  # noqa: B902
#     480                     retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# /usr/local/lib/python3.10/dist-packages/dlt/sources/helpers/requests/session.py in send(self, request, **kwargs)
#      59     def send(self, request, **kwargs):  # type: ignore[no-untyped-def]
#      60         kwargs.setdefault("timeout", self.timeout)
# ---> 61         return super().send(request, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     708
#     709         # Response manipulation hooks
# --> 710         r = dispatch_hook("response", hooks, r, **kwargs)
#     711
#     712         # Persist cookies
#
# /usr/local/lib/python3.10/dist-packages/requests/hooks.py in dispatch_hook(key, hooks, hook_data, **kwargs)
#      28             hooks = [hooks]
#      29         for hook in hooks:
# ---> 30             _hook_data = hook(hook_data, **kwargs)
#      31             if _hook_data is not None:
#      32                 hook_data = _hook_data
#
# /usr/local/lib/python3.10/dist-packages/dlt/sources/helpers/rest_client/client.py in raise_for_status(response, *args, **kwargs)
#     313
#     314 def raise_for_status(response: Response, *args: Any, **kwargs: Any) -> None:
# --> 315     response.raise_for_status()
#     316
#     317
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1022
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#    1026     def close(self):
#
# HTTPError: 403 Client Error: rate limit exceeded for url: https://api.github.com/repos/dlt-hub/dlt/stargazers

# %% [markdown]
# ### **Exercise 1: Pagination with RESTClient**
# Explore the cells above and answer the question below.
# #### Question
# What type of pagination we use for GitHub API?

# %% [markdown]
# ## **Authentication**
#
# To avoid this error you can use [GitHub API Authentication](https://docs.github.com/en/rest/authentication/authenticating-to-the-rest-api?apiVersion=2022-11-28):
#
# 1. Login to your GitHub account.
# 2. Generate [API token](https://docs.github.com/en/authentication/keeping-your-account-and-data-secure/creating-a-personal-access-token) (classic one!).
# 2.  Use it as an access token for GitHub API.

# %% [markdown]
# **! ATTENTION !**
#
# Never share your credentials in public and never hard-code them in your code. Use **environment variables** or **dlt secrets.toml**.

# %% [markdown]
# Create an environment variable for your access token.
#
# ![1_5wEevNCOf80GTHwptPTB4g.webp](data:image/webp;base64,...)
#
# If you have your token [ready in Colab](https://medium.com/@parthdasawant/how-to-use-secrets-in-google-colab-450c38e3ec75), you can directly use it:

# %%
import os
from google.colab import userdata

access_token = userdata.get('SECRET_KEY')

# %% [markdown]
# So now you can use `access_token` variable in the code below:

# %%
from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.auth import BearerTokenAuth


client = RESTClient(
    base_url="https://api.github.com",
    auth=BearerTokenAuth(token=access_token) # <--- put your token here
)

for page in client.paginate("repos/dlt-hub/dlt/stargazers"):
    print(page)
    break
# Out:
# [{'login': 'lalitpagaria', 'id': 19303690, 'node_id': 'MDQ6VXNlcjE5MzAzNjkw', 'avatar_url': 'https://avatars.githubusercontent.com/u/19303690?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/lalitpagaria', 'html_url': 'https://github.com/lalitpagaria', 'followers_url': 'https://api.github.com/users/lalitpagaria/followers', 'following_url': 'https://api.github.com/users/lalitpagaria/following{/other_user}', 'gists_url': 'https://api.github.com/users/lalitpagaria/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/lalitpagaria/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/lalitpagaria/subscriptions', 'organizations_url': 'https://api.github.com/users/lalitpagaria/orgs', 'repos_url': 'https://api.github.com/users/lalitpagaria/repos', 'events_url': 'https://api.github.com/users/lalitpagaria/events{/privacy}', 'received_events_url': 'https://api.github.com/users/lalitpagaria/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'nikitavoloboev', 'id': 6391776, 'node_id': 'MDQ6VXNlcjYzOTE3NzY=', 'avatar_url': 'https://avatars.githubusercontent.com/u/6391776?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/nikitavoloboev', 'html_url': 'https://github.com/nikitavoloboev', 'followers_url': 'https://api.github.com/users/nikitavoloboev/followers', 'following_url': 'https://api.github.com/users/nikitavoloboev/following{/other_user}', 'gists_url': 'https://api.github.com/users/nikitavoloboev/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/nikitavoloboev/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/nikitavoloboev/subscriptions', 'organizations_url': 'https://api.github.com/users/nikitavoloboev/orgs', 'repos_url': 'https://api.github.com/users/nikitavoloboev/repos', 'events_url': 'https://api.github.com/users/nikitavoloboev/events{/privacy}', 'received_events_url': 'https://api.github.com/users/nikitavoloboev/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'gerrykou', 'id': 13572514, 'node_id': 'MDQ6VXNlcjEzNTcyNTE0', 'avatar_url': 'https://avatars.githubusercontent.com/u/13572514?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/gerrykou', 'html_url': 'https://github.com/gerrykou', 'followers_url': 'https://api.github.com/users/gerrykou/followers', 'following_url': 'https://api.github.com/users/gerrykou/following{/other_user}', 'gists_url': 'https://api.github.com/users/gerrykou/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/gerrykou/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/gerrykou/subscriptions', 'organizations_url': 'https://api.github.com/users/gerrykou/orgs', 'repos_url': 'https://api.github.com/users/gerrykou/repos', 'events_url': 'https://api.github.com/users/gerrykou/events{/privacy}', 'received_events_url': 'https://api.github.com/users/gerrykou/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'jdmonty', 'id': 3614077, 'node_id': 'MDQ6VXNlcjM2MTQwNzc=', 'avatar_url': 'https://avatars.githubusercontent.com/u/3614077?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jdmonty', 'html_url': 'https://github.com/jdmonty', 'followers_url': 'https://api.github.com/users/jdmonty/followers', 'following_url': 'https://api.github.com/users/jdmonty/following{/other_user}', 'gists_url': 'https://api.github.com/users/jdmonty/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jdmonty/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jdmonty/subscriptions', 'organizations_url': 'https://api.github.com/users/jdmonty/orgs', 'repos_url': 'https://api.github.com/users/jdmonty/repos', 'events_url': 'https://api.github.com/users/jdmonty/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jdmonty/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login ...

# %% [markdown]
# So now we can rewrite our GitHub dlt pipeline using RestAPI Client and access_token.

# %%
import dlt
from dlt.sources.helpers import requests
from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.auth import BearerTokenAuth


# define new resource - github stargazers
@dlt.resource
def github_stargazers():
    client = RESTClient(
        base_url="https://api.github.com",
        auth=BearerTokenAuth(token=access_token)
    )

    for page in client.paginate("repos/dlt-hub/dlt/stargazers"):
        yield page


# define new dlt pipeline
pipeline = dlt.pipeline(destination="duckdb")


# run the pipeline with the new resource
load_info = pipeline.run(github_stargazers)
print(load_info)


# explore loaded data
pipeline.dataset(dataset_type="default").github_stargazers.df()
# Out:
# Pipeline dlt_colab_kernel_launcher load step completed in 2.11 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset dlt_colab_kernel_launcher_dataset
# The duckdb destination used duckdb:////content/dlt_colab_kernel_launcher.duckdb location to store data
# Load package 1736684225.1548073 is LOADED and contains no failed jobs
#                login        id               node_id  \
# 0       lalitpagaria  19303690  MDQ6VXNlcjE5MzAzNjkw
# 1     nikitavoloboev   6391776  MDQ6VXNlcjYzOTE3NzY=
# 2           gerrykou  13572514  MDQ6VXNlcjEzNTcyNTE0
# 3            jdmonty   3614077  MDQ6VXNlcjM2MTQwNzc=
# 4     alexeygrigorev    875246  MDQ6VXNlcjg3NTI0Ng==
# ...              ...       ...                   ...
# 2927        dannyeuu   6808348  MDQ6VXNlcjY4MDgzNDg=
# 2928       joshklein    251088  MDQ6VXNlcjI1MTA4OA==
# 2929           BViki   6351623  MDQ6VXNlcjYzNTE2MjM=
# 2930        weisberg   5054710  MDQ6VXNlcjUwNTQ3MTA=
# 2931           yatsu     14818      MDQ6VXNlcjE0ODE4
#
#                                              avatar_url gravatar_id  \
# 0     https://avatars.githubusercontent.com/u/193036...
# 1     https://avatars.githubusercontent.com/u/639177...
# 2     https://avatars.githubusercontent.com/u/135725...
# 3     https://avatars.githubusercontent.com/u/361407...
# 4     https://avatars.githubusercontent.com/u/875246...
# ...                                                 ...         ...
# 2927  https://avatars.githubusercontent.com/u/680834...
# 2928  https://avatars.githubusercontent.com/u/251088...
# 2929  https://avatars.githubusercontent.com/u/635162...
# 2930  https://avatars.githubusercontent.com/u/505471...
# 2931  https://avatars.githubusercontent.com/u/14818?v=4
#
#                                               url  \
# 0       https://api.github.com/users/lalitpagaria
# 1     https://api.github.com/users/nikitavoloboev
# 2           https://api.github.com/users/gerrykou
# 3            https://api.github.com/users/jdmonty
# 4     https://api.github.com/users/alexeygrigorev
# ...                                           ...
# 2927        https://api.github.com/users/dannyeuu
# 2928       https://api.github.com/users/joshklein
# 2929           https://api.github.com/users/BViki
# 2930        https://api.github.com/users/weisberg
# 2931           https://api.github.com/users/yatsu
#
#                                html_url  \
# 0       https://github.com/lalitpagaria
# 1     https://github.com/nikitavoloboev
# 2           https://github.com/gerrykou
# 3            https://github.com/jdmonty
# 4     https://github.com/alexeygrigorev
# ...                                 ...
# 2927        https://github.com/dannyeuu
# 2928       https://github.com/joshklein
# 2929           https://github.com/BViki
# 2930        https://github.com/weisberg
# 2931           https://github.com/yatsu
#
#                                           followers_url  \
# 0     https://api.github.com/users/lalitpagaria/foll...
# 1     https://api.github.com/users/nikitavoloboev/fo...
# 2       https://api.github.com/users/gerrykou/followers
# 3        https://api.github.com/users/jdmonty/followers
# 4     https://api.github.com/users/alexeygrigorev/fo...
# ...                                                 ...
# 2927    https://api.github.com/users/dannyeuu/followers
# 2928   https://api.github.com/users/joshklein/followers
# 2929       https://api.github.com/users/BViki/followers
# 2930    https://api.github.com/users/weisberg/followers
# 2931       https://api.github.com/users/yatsu/followers
#
#                                           following_url  \
# 0     https://api.github.com/users/lalitpagaria/foll...
# 1     https://api.github.com/users/nikitavoloboev/fo...
# 2     https://api.github.com/users/gerrykou/followin...
# 3     https://api.github.com/users/jdmonty/following...
# 4     https://api.github.com/users/alexeygrigorev/fo...
# ...                                                 ...
# 2927  https://api.github.com/users/dannyeuu/followin...
# 2928  https://api.github.com/users/joshklein/followi...
# 2929  https://api.github.com/users/BViki/following{/...
# 2930  https://api.github.com/users/weisberg/followin...
# 2931  https://api.github.com/users/yatsu/following{/...
#
#                                               gists_url  ...  \
# 0     https://api.github.com/users/lalitpagaria/gist...  ...
# 1     https://api.github.com/users/nikitavoloboev/gi...  ...
# 2     https://api.github.com/users/gerrykou/gists{/g...  ...
# 3     https://api.github.com/users/jdmonty/gists{/gi...  ...
# 4     https://api.github.com/users/alexeygrigorev/gi...  ...
# ...                                                 ...  ...
# 2927  https://api.github.com/users/dannyeuu/gists{/g...  ...
# 2928  https://api.github.com/users/joshklein/gists{/...  ...
# 2929  https://api.github.com/users/BViki/gists{/gist...  ...
# 2930  https://api.github.com/users/weisberg/gists{/g...  ...
# 2931  https://api.github.com/users/yatsu/gists{/gist...  ...
#
#                                       subscriptions_url  \
# 0     https://api.github.com/users/lalitpagaria/subs...
# 1     https://api.github.com/users/nikitavoloboev/su...
# 2     https://api.github.com/users/gerrykou/subscrip...
# 3     https://api.github.com/users/jdmonty/subscript...
# 4     https://api.github.com/users/alexeygrigorev/su...
# ...                                                 ...
# 2927  https://api.github.com/users/dannyeuu/subscrip...
# 2928  https://api.github.com/users/joshklein/subscri...
# 2929   https://api.github.com/users/BViki/subscriptions
# 2930  https://api.github.com/users/weisberg/subscrip...
# 2931   https://api.github.com/users/yatsu/subscriptions
#
#                                      organizations_url  \
# 0       https://api.github.com/users/lalitpagaria/orgs
# 1     https://api.github.com/users/nikitavoloboev/orgs
# 2           https://api.github.com/users/gerrykou/orgs
# 3            https://api.github.com/users/jdmonty/orgs
# 4     https://api.github.com/users/alexeygrigorev/orgs
# ...                                                ...
# 2927        https://api.github.com/users/dannyeuu/orgs
# 2928       https://api.github.com/users/joshklein/orgs
# 2929           https://api.github.com/users/BViki/orgs
# 2930        https://api.github.com/users/weisberg/orgs
# 2931           https://api.github.com/users/yatsu/orgs
#
#                                               repos_url  \
# 0       https://api.github.com/users/lalitpagaria/repos
# 1     https://api.github.com/users/nikitavoloboev/repos
# 2           https://api.github.com/users/gerrykou/repos
# 3            https://api.github.com/users/jdmonty/repos
# 4     https://api.github.com/users/alexeygrigorev/repos
# ...                                                 ...
# 2927        https://api.github.com/users/dannyeuu/repos
# 2928       https://api.github.com/users/joshklein/repos
# 2929           https://api.github.com/users/BViki/repos
# 2930        https://api.github.com/users/weisberg/repos
# 2931           https://api.github.com/users/yatsu/repos
#
#                                              events_url  \
# 0     https://api.github.com/users/lalitpagaria/even...
# 1     https://api.github.com/users/nikitavoloboev/ev...
# 2     https://api.github.com/users/gerrykou/events{/...
# 3     https://api.github.com/users/jdmonty/events{/p...
# 4     https://api.github.com/users/alexeygrigorev/ev...
# ...                                                 ...
# 2927  https://api.github.com/users/dannyeuu/events{/...
# 2928  https://api.github.com/users/joshklein/events{...
# 2929  https://api.github.com/users/BViki/events{/pri...
# 2930  https://api.github.com/users/weisberg/events{/...
# 2931  https://api.github.com/users/yatsu/events{/pri...
#
#                                     received_events_url  type user_view_type  \
# 0     https://api.github.com/users/lalitpagaria/rece...  User         public
# 1     https://api.github.com/users/nikitavoloboev/re...  User         public
# 2     https://api.github.com/users/gerrykou/received...  User         public
# 3     https://api.github.com/users/jdmonty/received_...  User         public
# 4     https://api.github.com/users/alexeygrigorev/re...  User         public
# ...                                                 ...   ...            ...
# 2927  https://api.github.com/users/dannyeuu/received...  User         public
# 2928  https://api.github.com/users/joshklein/receive...  User         public
# 2929  https://api.github.com/users/BViki/received_ev...  User         public
# 2930  https://api.github.com/users/weisberg/received...  User         public
# 2931  https://api.github.com/users/yatsu/received_ev...  User         public
#
#      site_admin        _dlt_load_id         _dlt_id
# 0         False  1736684225.1548073  IH05NRxJonmn3A
# 1         False  1736684225.1548073  9TCuJ2pg0vJNWw
# 2         False  1736684225.1548073  Mo0t0CwxqeFHnA
# 3         False  1736684225.1548073  CJa3+w17bQOkHA
# 4         False  1736684225.1548073  m3I2QBlQzOzoIg
# ...         ...                 ...             ...
# 2927      False  1736684225.1548073  oZupA9HYC1vOlQ
# 2928      False  1736684225.1548073  q1xbpqP3/JZIvQ
# 2929      False  1736684225.1548073  ODR/jSwrnPKuoA
# 2930      False  1736684225.1548073  KOKW8fCym/xkiA
# 2931      False  1736684225.1548073  3QF5WjOMCaHXfw
#
# [2932 rows x 21 columns]

# %% [markdown]
# You can see that all dlt [stargazers](https://github.com/dlt-hub/dlt/stargazers) were loaded into DuckDB destination.

# %% [markdown]
# ## **dlt configuration and secrets**
#
# In dlt, [configurations and secrets](https://dlthub.com/docs/general-usage/credentials/) are essential for setting up data pipelines.
#
# **Configurations** are **non-sensitive** settings that define the behavior of a data pipeline, including file paths, database hosts, timeouts, API URLs, and performance settings.
#
# On the other hand, **secrets** are **sensitive** data like passwords, API keys, and private keys, which should never be hard-coded to avoid security risks.
#
# These can be set up in various ways:
#
# * Environment variables
# * In code using `dlt.secrets` and `dlt.config`
# * Configuration files (`secrets.toml` and `config.toml`)
#
# We're gonna use `dlt.secrets.value` to define credentials in resources and sources. dlt automatically **extracts** configuration settings and secrets based on flexible naming conventions. It then **injects** these values where needed in code.
#
# **Note**: It's important to note that while you can put all configurations and credentials in the `dlt.secrets` (or `secrets.toml`) if it's more convenient, credentials cannot be placed in `dlt.config` (or `config.toml`) because dlt doesn't look for them there.

# %% [markdown]
# Let's create dlt pipeline for both endpoints `repos/dlt-hub/dlt/stargazers` and `orgs/dlt-hub/events`, we use `@dlt.source` to combine all resources in one place.

# %%
import dlt
from dlt.sources.helpers import requests
from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.auth import BearerTokenAuth


@dlt.source
def github_source():
    client = RESTClient(
            base_url="https://api.github.com",
            auth=BearerTokenAuth(token=access_token)
    )

    @dlt.resource
    def github_events():
        for page in client.paginate("orgs/dlt-hub/events"):
            yield page


    @dlt.resource
    def github_stargazers():
        for page in client.paginate("repos/dlt-hub/dlt/stargazers"):
            yield page

    return github_events, github_stargazers

# %% [markdown]
# Now we're gonna use `dlt.secrets.value` in our source to enable dlt secrets configuration. Rename `access_token` variable to `secret_key` because it's already defined.

# %%
exit()

# %%
import dlt
from dlt.sources.helpers import requests
from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.auth import BearerTokenAuth


@dlt.source
def github_source(access_token=dlt.secrets.value): # <--- set the secret variable "access_token" here
    client = RESTClient(
            base_url="https://api.github.com",
            auth=BearerTokenAuth(token=access_token)
    )

    @dlt.resource
    def github_events():
        for page in client.paginate("orgs/dlt-hub/events"):
            yield page


    @dlt.resource
    def github_stargazers():
        for page in client.paginate("repos/dlt-hub/dlt/stargazers"):
            yield page

    return github_events, github_stargazers

# %% [markdown]
# Configs are defined in a similar way but are accessed using `dlt.config.value`. However, since configuration variables are internally managed by `dlt`, it is unlikely that you would need to explicitly use `dlt.config.value` in most cases.

# %% [markdown]
# If you run the pipeline with `secret_key` as `dlt.secrets.value`, you will see the following error:

# %%
# define new dlt pipeline
pipeline = dlt.pipeline(destination="duckdb")


# run the pipeline with the new resource
load_info = pipeline.run(github_source())
print(load_info)
# Out:
# ---------------------------------------------------------------------------
# ConfigFieldMissingException               Traceback (most recent call last)
# <ipython-input-2-a17599ba3010> in <cell line: 6>()
#       4
#       5 # run the pipeline with the new resource
# ----> 6 load_info = pipeline.run(github_source())
#       7 print(load_info)
#
# /usr/local/lib/python3.10/dist-packages/dlt/extract/decorators.py in __call__(self, *args, **kwargs)
#     194                 resource.apply_hints(schema_contract=self.schema_contract)
#     195         else:
# --> 196             source = self._deco_f(*args, **kwargs)
#     197         return source
#     198
#
# /usr/local/lib/python3.10/dist-packages/dlt/extract/decorators.py in _wrap(*args, **kwargs)
#     278                     )
#     279                 ):
# --> 280                     rv = conf_f(*args, **kwargs)
#     281                     return _eval_rv(rv, schema_copy)
#     282
#
# /usr/local/lib/python3.10/dist-packages/dlt/common/configuration/inject.py in _wrap(*args, **kwargs)
#     241                 config = last_config(**kwargs)
#     242             else:
# --> 243                 config = resolve_config(bound_args, accept_partial_=accept_partial)
#     244
#     245             # call the function with resolved config
#
# /usr/local/lib/python3.10/dist-packages/dlt/common/configuration/inject.py in resolve_config(bound_args, accept_partial_)
#     169             with inject_section(section_context, lock_context=lock_context_on_injection):
#     170                 # print(f"RESOLVE CONF in inject: {f.__name__}: {section_context.sections} vs {sections} in {bound_args.arguments}")
# --> 171                 return resolve_configuration(
#     172                     config or SPEC(),
#     173                     explicit_value=bound_args.arguments,
#
# /usr/local/lib/python3.10/dist-packages/dlt/common/configuration/resolve.py in resolve_configuration(config, sections, explicit_value, accept_partial)
#      65             log_traces(None, config.__section__, type(config), explicit_value, None, traces)
#      66
# ---> 67     return _resolve_configuration(config, sections, (), explicit_value, accept_partial)
#      68
#      69
#
# /usr/local/lib/python3.10/dist-packages/dlt/common/configuration/resolve.py in _resolve_configuration(config, explicit_sections, embedded_sections, explicit_value, accept_partial)
#     162             # if native representation didn't fully resolve the config, we try to resolve field by field
#     163             if not config.is_resolved():
# --> 164                 _resolve_config_fields(
#     165                     config, explicit_value, explicit_sections, embedded_sections, accept_partial
#     166                 )
#
# /usr/local/lib/python3.10/dist-packages/dlt/common/configuration/resolve.py in _resolve_config_fields(config, explicit_values, explicit_sections, embedded_sections, accept_partial)
#     298
#     299     if unresolved_fields:
# --> 300         raise ConfigFieldMissingException(type(config).__name__, unresolved_fields)
#     301
#     302
#
# ConfigFieldMissingException: Following fields are missing: ['access_token'] in configuration with spec GithubSourceConfiguration
# 	for field "access_token" config providers and keys were tried in following order:
# 		In Environment Variables key DLT_COLAB_KERNEL_LAUNCHER__SOURCES____MAIN____GITHUB_SOURCE__ACCESS_TOKEN was not found.
# 		In Environment Variables key DLT_COLAB_KERNEL_LAUNCHER__SOURCES____MAIN____ACCESS_TOKEN was not found.
# 		In Environment Variables key DLT_COLAB_KERNEL_LAUNCHER__SOURCES__ACCESS_TOKEN was not found.
# 		In Environment Variables key DLT_COLAB_KERNEL_LAUNCHER__ACCESS_TOKEN was not found.
# 		In Environment Variables key SOURCES____MAIN____GITHUB_SOURCE__ACCESS_TOKEN was not found.
# 		In Environment Variables key SOURCES____MAIN____ACCESS_TOKEN was not found.
# 		In Environment Variables key SOURCES__ACCESS_TOKEN was not found.
# 		In Environment Variables key ACCESS_TOKEN was not found.
# WARNING: dlt looks for .dlt folder in your current working directory and your cwd (/content) is different from directory of your pipeline script (/usr/local/lib/python3.10/dist-packages).
# If you keep your secret files in the same folder as your pipeline script but run your script from some other folder, secrets/configs will not be found
# Please refer to https://dlthub.com/docs/general-usage/credentials for more information

# %% [markdown]
# ^ That is what happens if you set `dlt.secrets.value` for any variable in your dlt pipeline, but don't set the secret value up.
#
# dlt is looking for secrets in following formats:
#
# ```python
# ConfigFieldMissingException: Following fields are missing: ['access_token'] in configuration with spec GithubSourceConfiguration
# 	for field "access_token" config providers and keys were tried in following order:
# 		In Environment Variables key DLT_COLAB_KERNEL_LAUNCHER__SOURCES____MAIN____GITHUB_SOURCE__ACCESS_TOKEN was not found.
# 		In Environment Variables key DLT_COLAB_KERNEL_LAUNCHER__SOURCES____MAIN____ACCESS_TOKEN was not found.
# 		In Environment Variables key DLT_COLAB_KERNEL_LAUNCHER__SOURCES__ACCESS_TOKEN was not found.
# 		In Environment Variables key DLT_COLAB_KERNEL_LAUNCHER__ACCESS_TOKEN was not found.
# 		In Environment Variables key SOURCES____MAIN____GITHUB_SOURCE__ACCESS_TOKEN was not found.
# 		In Environment Variables key SOURCES____MAIN____ACCESS_TOKEN was not found.
# 		In Environment Variables key SOURCES__ACCESS_TOKEN was not found.
# 		In Environment Variables key ACCESS_TOKEN was not found.
# WARNING: dlt looks for .dlt folder in your current working directory and your cwd (/content) is different from directory of your pipeline script (/usr/local/lib/python3.10/dist-packages).
# If you keep your secret files in the same folder as your pipeline script but run your script from some other folder, secrets/configs will not be found
# Please refer to https://dlthub.com/docs/general-usage/credentials for more information
# ```

# %% [markdown]
# To define `access_token` secret value we can use:
#
# 1. `dlt.secrets` in code (recommended for secret vaults or dynamic creds)
# 2. Environment variables (recomnended for prod)
# 3. `secrets.toml` file (recommended for local dev)

# %% [markdown]
# ### **Use `dlt.secrets` in code**
#
# You can easily rewrite your secret right in the Python code. It's especially convenient if you take credentials from third-party secret providers, or if you want to update credentials and configs dinamically.

# %%
import os
from google.colab import userdata

dlt.secrets["access_token"] = userdata.get('SECRET_KEY')

# define new dlt pipeline
pipeline = dlt.pipeline(destination="duckdb")


# run the pipeline with the new resource
load_info = pipeline.run(github_source())
print(load_info)
# Out:
# Pipeline dlt_colab_kernel_launcher load step completed in 5.47 seconds
# 2 load package(s) were loaded to destination duckdb and into dataset dlt_colab_kernel_launcher_dataset
# The duckdb destination used duckdb:////content/dlt_colab_kernel_launcher.duckdb location to store data
# Load package 1736684681.6599302 is LOADED and contains no failed jobs
# Load package 1736684703.180921 is LOADED and contains no failed jobs

# %% [markdown]
# Alternatively you can set:
#
# ```python
# dlt.secrets["sources.access_token"] = userdata.get('SECRET_KEY')
# dlt.secrets["sources.____main____.access_token"] = userdata.get('SECRET_KEY')
# dlt.secrets["sources.____main____.github_source.access_token"] = userdata.get('SECRET_KEY')
# ...
# ```

# %% [markdown]
# * `sources` is a special word;
#
# * `__main__` is a python module name;
#
# * `github_source` is the resource name;
#
# * `access_token` is the secret variable name.
#
#
# So dlt looks for secrets according to this hierarchy:
# ```
# pipeline_name
#     |
#     |-sources
#         |
#         |-<module name>
#             |
#             |-<source function 1 name>
#                 |
#                 |- secret variable 1
#                 |- secret variable 2
# ```
#
# To keep the **naming convention** flexible, dlt looks for a lot of **possible combinations** of key names, starting from the most specific possible path. Then, if the value is not found, it removes the right-most section and tries again.

# %% [markdown]
# ### **Exercise 2: Run pipeline with `dlt.secrets.value`**
#
# Explore the cells above and answer the question below using `sql_client`.
#
# #### Question
#
# Who has id=`17202864` in the `stargazers` table? Use `sql_client`.

# %%
import dlt
from dlt.sources.helpers import requests
from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.auth import BearerTokenAuth


@dlt.source
def github_source(access_token=dlt.secrets.value): # <--- set the secret variable "access_token" here
    client = RESTClient(
            base_url="https://api.github.com",
            auth=BearerTokenAuth(token=access_token)
    )

    @dlt.resource
    def github_events():
        for page in client.paginate("orgs/dlt-hub/events"):
            yield page


    @dlt.resource
    def github_stargazers():
        for page in client.paginate("repos/dlt-hub/dlt/stargazers"):
            yield page

    return github_events, github_stargazers

# %%
# define new dlt pipeline
pipeline = dlt.pipeline(destination="duckdb")


# run the pipeline with the new resource
load_info = pipeline.run(github_source())
print(load_info)
# Out:
# Pipeline dlt_colab_kernel_launcher load step completed in 5.72 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset dlt_colab_kernel_launcher_dataset
# The duckdb destination used duckdb:////content/dlt_colab_kernel_launcher.duckdb location to store data
# Load package 1736685312.282393 is LOADED and contains no failed jobs

# %% [markdown]
# To answer the question "Who has id=17202864 in the stargazers table?" using the sql_client, we need to query the github_stargazers table in the DuckDB database where the data was loaded. Here's how you can do it:

# %%
# Query data from 'github_stargazers' using the SQL client
with pipeline.sql_client() as client:
    with client.execute_query("SELECT login FROM github_stargazers WHERE id = 17202864") as cursor:
        data = cursor.fetchall()

# Display the result
if data:
    print(f"The user with id=17202864 is: {data[0][0]}")
else:
    print("No user found with id=17202864.")
# Out:
# The user with id=17202864 is: rudolfix

# %% [markdown]
# ####Explanation:
# #####1. pipeline.sql_client(): This creates a SQL client connected to the DuckDB database where the github_stargazers table is stored.
#
# #####2. client.execute_query(): Executes the SQL query to retrieve the login of the user with id=17202864 from the github_stargazers table.
#
# #####3. cursor.fetchall(): Fetches all rows returned by the query. Since we are querying by a unique id, there will be at most one row.
#
# print(data[0][0]): If a user is found, the login (username) of the user is printed. If no user is found, a message is displayed.

# %% [markdown]
# ---
# ###  **Use environment variables**
#
# Let's set ENV in the one of the dlt formats: `ACCESS_TOKEN`.

# %%
import os
from google.colab import userdata

os.environ["ACCESS_TOKEN"] = userdata.get('SECRET_KEY')

# define new dlt pipeline
pipeline = dlt.pipeline(destination="duckdb")


# run the pipeline with the new resource
load_info = pipeline.run(github_source())
print(load_info)
# Out:
# Pipeline dlt_colab_kernel_launcher load step completed in 3.97 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset dlt_colab_kernel_launcher_dataset
# The duckdb destination used duckdb:////content/dlt_colab_kernel_launcher.duckdb location to store data
# Load package 1736684724.1758082 is LOADED and contains no failed jobs

# %% [markdown]
# Alternatively you can set:
#
# ```python
# os.environ["SOURCES__ACCESS_TOKEN"] = userdata.get('SECRET_KEY')
# os.environ["SOURCES____MAIN____ACCESS_TOKEN"] = userdata.get('SECRET_KEY')
# os.environ["SOURCES____MAIN____GITHUB_SOURCE__ACCESS_TOKEN"] = userdata.get('SECRET_KEY')
# ...
# ```

# %% [markdown]
# **How does it work?**
#
# `dlt` **automatically extracts** configuration settings and secrets based on flexible naming conventions.
#
# It then **injects** these values where needed in functions decorated with `@dlt.source`, `@dlt.resource`, or `@dlt.destination`.
#
#
# >dlt uses a specific naming hierarchy to search for the secrets and config values. This makes configurations and secrets easy to manage.
# >
# > The naming convention for **environment variables** in dlt follows a specific pattern. All names are **capitalized** and sections are separated with **double underscores** __ , e.g.  `SOURCES____MAIN____GITHUB_SOURCE__SECRET_KEY`.

# %% [markdown]
# ---
# ###  **Use dlt `secrets.toml` or `config.toml`**

# %% [markdown]
# > Please note that Colab is not well-suited for using `secrets.toml` or `config.toml` files. As a result, these sections will provide instructions rather than code cells, detailing how to use them in a local environment. You should test this functionality on your own machine. For Colab, it is recommended to use environment variables instead.

# %% [markdown]
# The `secrets.toml` file - along with the `config.toml` file - should be stored in the `.dlt` directory where your pipeline code is located:
#
# ```
# /your_project_directory
# │
# ├── .dlt
# │   ├── secrets.toml
# │   └── config.toml
# │
# └── my_pipeline.py
# ```
#
# Read more about adding [credentials](https://dlthub.com/docs/walkthroughs/add_credentials) here.

# %% [markdown]
# To set credentials via TOMLs you would first add your access token to `secrets.toml`:
#
# ```toml
# # .dlt/secrets.toml
#
# [sources]
# secret_key = "your_access_token"
# ```

# %% [markdown]
# Alternatively you can set:
#
# ```
# [sources]
# secret_key = "your_access_token"
# ```
# is equal to:
#
# ```
# secret_key = "your_access_token"
# ```
#
# and to:
#
# ```
# [sources.____main____]
# secret_key = "your_access_token"
# ```
# and to:
#
# ```
# [sources.____main____.github_source]
# secret_key = "your_access_token"
# ```

# %% [markdown]
# ### **Configure Secrets in Colab**
#
# You can configure secrets using **Secrets** sidebar. Just create a variable with the name `secrets.toml` and paste the content of the toml file from your `.dlt` folder into it. We support `config.toml` variable as well.
#
# Open **Secrets** sidebar, press "Add new secret", create variable with name `secrets.toml` and copy-paste secrets in Value field and Enable it:
#
# ```
# [sources]
# secret_key = "your_access_token"
# ```
#
#
# >dlt will not reload the secrets automatically. **Please restart your interpreter** in Colab options when you add/change content of the variables above.

# %% [markdown]
# ![Screenshot 2024-11-29 at 14.38.01.png](data:image/png;base64,...)

# %% [markdown]
# ✅ ▶ Proceed to the [next lesson](https://colab.research.google.com/drive/1mfqZulsuFDc7h27d6joe2_Dduvl1uM-2?usp=sharing)!
